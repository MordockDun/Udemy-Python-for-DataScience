# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
y
# Out:
# array([  0.  ,   0.25,   1.  ,   2.25,   4.  ,   6.25,   9.  ,  12.25,
#         16.  ,  20.25,  25.  ])

# %%
plt.plot(x,y,'r')
plt.xlabel('x Achse')
plt.ylabel("y Achse")
plt.title("Diagramm Titel")
#plt.show()
# Out:
# Text(0.5,1,'Diagramm Titel')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x,'g*-')

# %%
af = plt.figure()

axes = af.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y,'b')
axes.set_xlabel("x Label")
axes.set_ylabel("y Label")
axes.set_title("Überschrift")
# Out:
# Text(0.5,1,'Überschrift')

# %%
af = plt.figure()

axes1 = af.add_axes([0.1,0.1,0.8,0.8])
axes2 = af.add_axes([0.2,0.2,0.4,0.3])

axes1.plot(x,y,'b')
axes1.set_xlabel("X")
axes1.set_ylabel("Y")
axes1.set_title("GROSSE")

axes2.plot(y,x,'r')
axes2.set_xlabel("X")
axes2.set_ylabel("Y")
axes2.set_title("kleine")
# Out:
# Text(0.5,1,'kleine')

# %%
diag, axes = plt.subplots(nrows=1,ncols=2)

for ax in axes:
    ax.plot(x,y)
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_title("Titel")
    
plt.tight_layout()

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019933D2C208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019933A46828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019932A08C50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000199329B0898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019932756E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000199326D6C88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001993263F518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000199325F5080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000199326C7F98>]], dtype=object)

# %%
diag = plt.figure(figsize=(8,4),dpi=100)
ax = diag.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
diag, axes = plt.subplots(figsize=(12,3))
axes.plot(x,y)

# %%
diag.savefig("dateiname.png", dpi=200)

# %%
ax.set_title("Titel")
# Out:
# Text(0.5,1,'Titel')

# %%
diag = plt.figure()

ax = diag.add_axes([0,0,1,1])
ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="x**3")

ax.legend(loc=3)

# %%
diag, ax = plt.subplots()
ax.plot(x, x**2, color='blue')
ax.set_ylim([0,5])
ax.set_xlim([0,1])
# Out:
# (0, 1)
